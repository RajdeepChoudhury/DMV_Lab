# %% [markdown]
# # <span style = color:Skyblue> Dynamic programming of scatterplot
# ***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n1 = np.array(list(map(int, input('Enter data 1:').split())))
n2 = np.array(list(map(int, input('Enter data 2:').split())))
plt.scatter(n1,n2)
plt.title("Points scored by students\n",fontsize = 20, color = 'Green')
plt.grid(color = 'grey')
plt.xlabel("Number of Points")
plt.ylabel("Number of Students")
plt.show()
# Out:
# Enter data 1: 1 2 3 4 2 3 4 2 6 7 7 8 4 4 2
# Enter data 2: 2 3 4 5 6 2 5 3 4 5 2 6 2 3 1
