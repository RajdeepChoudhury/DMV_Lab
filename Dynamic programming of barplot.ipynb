# %% [markdown]
# # <span style = color:Skyblue> Dynamic programming of barplot
# ***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
n1 = np.array(list(map(int, input('Enter data 1:').split())))
n2 = np.array(list(map(int, input('Enter data 2:').split())))
plt.bar(n1,n2)
plt.title("Points scored by students\n",fontsize = 20, color = 'Green')
plt.grid(color = 'grey')
plt.xlabel("Number of Points")
plt.ylabel("Number of Students")
plt.show()
# Out:
# Enter data 1: 1 2 3 4 5
# Enter data 2: 3 4 6 7 8
