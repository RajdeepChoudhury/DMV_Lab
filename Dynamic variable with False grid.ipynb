# %%
import matplotlib.pyplot as plt
x = list(map(int,input('Enter x element').split())) 
y = list(map(int,input('Enter y element').split())) 
plt.plot(x,y,marker = 'o')
plt.xlabel('X values (Independent Variable):')
plt.ylabel('Y values (Dependent Variable):')
plt.title('X-Y Axis Data Plot')
plt.grid(False)
plt.show()
# Out:
# Enter x element 1 3 6 7 9
# Enter y element 2 4 6 8 9
